# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("covid_19_india.csv",index_col=0)

# %%
data.head()
# Out:
#            Date     Time State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    2020-01-30  6:00 PM               Kerala                       1
# 2    2020-01-31  6:00 PM               Kerala                       1
# 3    2020-02-01  6:00 PM               Kerala                       2
# 4    2020-02-02  6:00 PM               Kerala                       3
# 5    2020-02-03  6:00 PM               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3

# %%
data.describe()
# Out:
#               Cured         Deaths     Confirmed
# count  1.811000e+04   18110.000000  1.811000e+04
# mean   2.786375e+05    4052.402264  3.010314e+05
# std    6.148909e+05   10919.076411  6.561489e+05
# min    0.000000e+00       0.000000  0.000000e+00
# 25%    3.360250e+03      32.000000  4.376750e+03
# 50%    3.336400e+04     588.000000  3.977350e+04
# 75%    2.788698e+05    3643.750000  3.001498e+05
# max    6.159676e+06  134201.000000  6.363442e+06

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['Deaths'])
# Out:
# <BarContainer object of 18110 artists>

# %%
data['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep', 'Telangana', 'Dadra and Nagar Haveli', 'Bihar****',
#        'Madhya Pradesh***', 'Himanchal Pradesh', 'Karanataka',
#        'Maharashtra***'], dtype=object)

# %%
data[data['State/UnionTerritory']=='Cases being reassigned to states'].head(20)
# Out:
#             Date     Time              State/UnionTerritory  \
# Sno
# 2134  2020-05-20  8:00 AM  Cases being reassigned to states
# 2168  2020-05-21  8:00 AM  Cases being reassigned to states
# 2202  2020-05-22  8:00 AM  Cases being reassigned to states
# 2236  2020-05-23  8:00 AM  Cases being reassigned to states
# 2271  2020-05-24  8:00 AM  Cases being reassigned to states
# 2306  2020-05-25  8:00 AM  Cases being reassigned to states
# 2342  2020-05-26  8:00 AM  Cases being reassigned to states
# 2378  2020-05-27  8:00 AM  Cases being reassigned to states
# 2414  2020-05-28  8:00 AM  Cases being reassigned to states
# 2450  2020-05-29  8:00 AM  Cases being reassigned to states
# 2486  2020-05-30  8:00 AM  Cases being reassigned to states
# 2522  2020-05-31  8:00 AM  Cases being reassigned to states
# 2558  2020-06-01  8:00 AM  Cases being reassigned to states
# 2594  2020-06-02  8:00 AM  Cases being reassigned to states
# ...

# %%
data=data.replace("Karanataka","Karnataka")

# %%
data['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telengana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep', 'Telangana', 'Dadra and Nagar Haveli', 'Bihar****',
#        'Madhya Pradesh***', 'Himanchal Pradesh', 'Maharashtra***'],
#       dtype=object)

# %%
data=data.replace("Maharashtra***","Maharashtra")
data=data.replace("Himanchal Pradesh","Himachal Pradesh")
data=data.replace("Madhya Pradesh***","Madhya Pradesh")
data=data.replace("Bihar****","Bihar")
data=data.replace("Telengana","Telangana")

# %%
data['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'Uttar Pradesh',
#        'Haryana', 'Ladakh', 'Tamil Nadu', 'Karnataka', 'Maharashtra',
#        'Punjab', 'Jammu and Kashmir', 'Andhra Pradesh', 'Uttarakhand',
#        'Odisha', 'Puducherry', 'West Bengal', 'Chhattisgarh',
#        'Chandigarh', 'Gujarat', 'Himachal Pradesh', 'Madhya Pradesh',
#        'Bihar', 'Manipur', 'Mizoram', 'Andaman and Nicobar Islands',
#        'Goa', 'Unassigned', 'Assam', 'Jharkhand', 'Arunachal Pradesh',
#        'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman & Diu',
#        'Lakshadweep', 'Dadra and Nagar Haveli'], dtype=object)

# %%
data=data.replace("Uttar Pradesh","U.P")
data=data.replace("Tamil Nadu","T.N")
data=data.replace("Jammu and Kashmir","J.K")
data=data.replace("Andhra Pradesh","A.P")
data=data.replace("West Bengal","W.B")
data=data.replace("Himachal Pradesh","H.P")
data=data.replace("Madhya Pradesh","M.P")
data=data.replace("Andaman and Nicobar Islands","Andaman")
data=data.replace("Arunachal Pradesh","A.R")
data=data.replace("Daman & Diu","Daman")
data=data.replace("Dadra and Nagar Haveli","Dadra")

# %%
data['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'U.P', 'Haryana',
#        'Ladakh', 'T.N', 'Karnataka', 'Maharashtra', 'Punjab', 'J.K',
#        'A.P', 'Uttarakhand', 'Odisha', 'Puducherry', 'W.B',
#        'Chhattisgarh', 'Chandigarh', 'Gujarat', 'H.P', 'M.P', 'Bihar',
#        'Manipur', 'Mizoram', 'Andaman', 'Goa', 'Unassigned', 'Assam',
#        'Jharkhand', 'A.R', 'Tripura', 'Nagaland', 'Meghalaya',
#        'Dadra and Nagar Haveli and Daman and Diu',
#        'Cases being reassigned to states', 'Sikkim', 'Daman',
#        'Lakshadweep', 'Dadra'], dtype=object)

# %%
data[data['State/UnionTerritory']=="Unassigned"].head()
# Out:
#            Date     Time State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 501  2020-03-30  9:30 PM           Unassigned                       -
# 529  2020-03-31  8:30 PM           Unassigned                       -
# 618  2020-04-03  6:00 PM           Unassigned                       -
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 501                        -      0       0         46
# 529                        -      0       0         38
# 618                        -      0       0         77

# %%
data=data.replace("Unassigned","na")
data=data.replace("Dadra and Nagar Haveli and Daman and Diu","na")

# %%
data=data.dropna()

# %%
data['State/UnionTerritory'].unique()
# Out:
# array(['Kerala', 'Telangana', 'Delhi', 'Rajasthan', 'U.P', 'Haryana',
#        'Ladakh', 'T.N', 'Karnataka', 'Maharashtra', 'Punjab', 'J.K',
#        'A.P', 'Uttarakhand', 'Odisha', 'Puducherry', 'W.B',
#        'Chhattisgarh', 'Chandigarh', 'Gujarat', 'H.P', 'M.P', 'Bihar',
#        'Manipur', 'Mizoram', 'Andaman', 'Goa', 'na', 'Assam', 'Jharkhand',
#        'A.R', 'Tripura', 'Nagaland', 'Meghalaya',
#        'Cases being reassigned to states', 'Sikkim', 'Daman',
#        'Lakshadweep', 'Dadra'], dtype=object)

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['Deaths'])
# Out:
# <BarContainer object of 18110 artists>

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['Confirmed'])
# Out:
# <BarContainer object of 18110 artists>

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['Cured'])
# Out:
# <BarContainer object of 18110 artists>

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['Deaths']/data['Confirmed'])
# Out:
# <BarContainer object of 18110 artists>

# %%
data=data.drop(columns=['Time'])

# %%
plt.figure(figsize=(50,10))
plt.bar(data['State/UnionTerritory'],data['ConfirmedForeignNational'])
# Out:
# <BarContainer object of 18110 artists>

# %%
data['ConfirmedForeignNational'].max()
# Out:
# '9'

# %%
plt.figure(figsize=(50,10))
plt.plot(data['Date'],data['Confirmed'])

# %%
plt.figure(figsize=(50,10))
plt.plot(data['Date'],data['Deaths'])

# %%
sns.heatmap(data.corr())

# %%
data.head()
# Out:
#            Date State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    2020-01-30               Kerala                       1
# 2    2020-01-31               Kerala                       1
# 3    2020-02-01               Kerala                       2
# 4    2020-02-02               Kerala                       3
# 5    2020-02-03               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed
# Sno
# 1                          0      0       0          1
# 2                          0      0       0          1
# 3                          0      0       0          2
# 4                          0      0       0          3
# 5                          0      0       0          3

# %%
data.columns
# Out:
# Index(['Date', 'State/UnionTerritory', 'ConfirmedIndianNational',
#        'ConfirmedForeignNational', 'Cured', 'Deaths', 'Confirmed'],
#       dtype='object')

# %%
states={}
i=1
for state in data['State/UnionTerritory'] :
    if state in states:
        continue
    else:
        states[state]=i
        i+=1

# %%
i=1
x=[]
for state in data['State/UnionTerritory'] :
    x.append(states[state])
#     print(states[state])

# %%
data['States']=x

# %%
data[['Year','Month','Day']]=data["Date"].str.split("-",expand=True)

# %%
data.head()
# Out:
#            Date State/UnionTerritory ConfirmedIndianNational  \
# Sno
# 1    2020-01-30               Kerala                       1
# 2    2020-01-31               Kerala                       1
# 3    2020-02-01               Kerala                       2
# 4    2020-02-02               Kerala                       3
# 5    2020-02-03               Kerala                       3
#
#     ConfirmedForeignNational  Cured  Deaths  Confirmed  States  Year Month Day
# Sno
# 1                          0      0       0          1       1  2020    01  30
# 2                          0      0       0          1       1  2020    01  31
# 3                          0      0       0          2       1  2020    02  01
# 4                          0      0       0          3       1  2020    02  02
# 5                          0      0       0          3       1  2020    02  03
